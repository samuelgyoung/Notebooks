# %%
# SAMPLE DATA SET

import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# %matplotlib inline
import seaborn as sns; sns.set()
sns.pairplot(iris, hue='species', size=1.5);

# %%
#SPECIES IS THE TARGET, SO WE REMOVE IT

X_iris = iris.drop('species', axis=1)
X_iris.shape
# Out:
# (150, 4)

# %%
#WE KEEP THE TARGET
y_iris = iris['species']
y_iris.shape
# Out:
# (150,)

# %% [markdown]
# ![05.02-samples-features-6d1a0bd3e020404868c3e888e0f2c783.png](attachment:05.02-samples-features-6d1a0bd3e020404868c3e888e0f2c783.png)#

# %%
from sklearn.cross_validation import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris,
                                                random_state=1)

# %%
Xtrain
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 54            6.5          2.8           4.6          1.5
# 108           6.7          2.5           5.8          1.8
# 112           6.8          3.0           5.5          2.1
# 17            5.1          3.5           1.4          0.3
# 119           6.0          2.2           5.0          1.5
# 103           6.3          2.9           5.6          1.8
# 58            6.6          2.9           4.6          1.3
# 118           7.7          2.6           6.9          2.3
# 18            5.7          3.8           1.7          0.3
# 4             5.0          3.6           1.4          0.2
# 45            4.8          3.0           1.4          0.3
# 59            5.2          2.7           3.9          1.4
# 39            5.1          3.4           1.5          0.2
# 36            5.5          3.5           1.3          0.2
# 117           7.7          3.8           6.7          2.2
# 139           6.9          3.1           5.4          2.1
# 107           7.3          2.9           6.3          1.8
# 132           6.4          2.8           5.6          2.2
# 126           6.2          2.8           4.8          1.8
# 85            6.0          3.4           4.5          1.6
# 122           7.7          2.8           6.7          2.0
# 95            5.7          3.0           4.2          1.2
# 11            4.8          3.4           1.6          0.2
# 113           5.7          2.5           5.0          2.0
# 123           6.3          2.7           4.9          1.8
# 12            4.8          3.0           1.4          0.1
# 2             4.7          3.2           1.3          0.2
# 104           6.5          3.0           5.8          2.2
# 6             4.6          3.4           1.4          0.3
# 127           6.1          3.0           4.9          1.8
# ..            ...          ...           ...          ...
# 47            4.6          3.2           1.4          0.2
# 115           6.4          3.2           5.3          2.3
# 13            4.3          3.0           1.1          0.1
# 88            5.6          3.0           4.1          1.3
# 8             4.4          2.9           1.4          0.2
# 81            5.5          2.4           3.7          1.0
# 60            5.0          2.0           3.5          1.0
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 57            4.9          2.4           3.3          1.0
# 22            4.6          3.6           1.0          0.2
# 61            5.9          3.0           4.2          1.5
# 63            6.1          2.9           4.7          1.4
# 7             5.0          3.4           1.5          0.2
# 86            6.7          3.1           4.7          1.5
# 96            5.7          2.9           4.2          1.3
# 68            6.2          2.2           4.5          1.5
# 50            7.0          3.2           4.7          1.4
# 101           5.8          2.7           5.1          1.9
# 20            5.4          3.4           1.7          0.2
# 25            5.0          3.0           1.6          0.2
# 134           6.1          2.6           5.6          1.4
# 71            6.1          2.8           4.0          1.3
# 129           7.2          3.0           5.8          1.6
# 79            5.7          2.6           3.5          1.0
# 133           6.3          2.8           5.1          1.5
# 137           6.4          3.1           5.5          1.8
# 72            6.3          2.5           4.9          1.5
# 140           6.7          3.1           5.6          2.4
# 37            4.9          3.6           1.4          0.1
#
# [112 rows x 4 columns]

# %%
from sklearn.naive_bayes import GaussianNB # 1. choose model class
model = GaussianNB()                       # 2. instantiate model
model.fit(Xtrain, ytrain)                  # 3. fit model to data
y_model = model.predict(Xtest)             # 4. predict on new data

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)
# Out:
# 0.97368421052631582

# %% [markdown]
# # With an accuracy topping 97%, we see that even this very naive classification algorithm is effective for this particular dataset!

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([5.1 ,3.5 ,1.4 ,0.2])
a = a.reshape(1,-1)

# %%
model.predict(a)
# Out:
# array(['setosa'],
#       dtype='|S10')
