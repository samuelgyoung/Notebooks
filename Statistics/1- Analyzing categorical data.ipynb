# %% [markdown]
# <h1>Analyzing categorical data</h1>
#
# https://www.khanacademy.org/math/statistics-probability/analyzing-categorical-data
#
# <h2>Analyzing one categorical variable</h2>
#
# <h3>Individuals, variables, and categorical & quantitative data</h3>
# Definitions:
#
# (Data) Individuals : Objects described by a set of data.
#
# (Data) Catagorical : Data the fits into a "bucket"
#
# (Data) Quantitive : Numerical

# %% [markdown]
# <h2>Two-way tables</h2>
#
# <h3>Two-way frequency tables</h3>
#
# Gives numbers of each category in the data. <b>Note, it can have more than 2 columns and rows!</b>
#
# Example Below:

# %%
from IPython.display import Image
Image(filename='twowayTable.jpg')

# %% [markdown]
# <h3>Two-way relative frequency tables</h3>
#
# Thinks in frequencies of value, while a regular two way table gives you numbers

# %%
Image(filename='twoWayFreqencyTable.jpg')

# %% [markdown]
# <h2>Distributions in two-way tables</h2>
#
# <h3>Marginal and conditional distributions</h3>
#
# Dividing a total for a row (or column) by the Total to get a percent for each group.

# %%
Image(filename='MarginalDistribution.jpg')

# %% [markdown]
# Conditional:  Example- what was the % correct Given someone studied 41-60 hours?
#
#     Always in percent.

# %%
Image(filename='ConditionalDistribution.jpg')
