# %%
import numpy as np, matplotlib.pyplot as plt, matplotlib.ticker as ticker, IPython.display as ipd
import librosa, librosa.display

# %%
#https://towardsdatascience.com/audio-deep-learning-made-simple-part-1-state-of-the-art-techniques-da1d3dff2504

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (0.10.0.post2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.0)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (4.6.3)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: requests in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from pooch<1.7,>=1.0->librosa) (2.29.0)
# Requirement already satisfied: packaging in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from pooch<1.7,>=1.0->librosa) (23.0)
# Requirement already satisfied: appdirs in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from requests->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from requests->pooch<1.7,>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa

# Load the audio file
AUDIO_FILE = '/Volumes/data/roboCallerData/isRobotWAV/voicemail-292.wav'
samples, sample_rate = librosa.load(AUDIO_FILE, sr=128)

# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in /Users/sgyoung/anaconda3/lib/python3.11/site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install ffmpeg-python

# %%
#pip install ffmpeg

# %%
import librosa.display
import matplotlib.pyplot as plt

# x-axis has been converted to time using our sample rate. 
# matplotlib plt.plot(y), would output the same figure, but with sample 
# number on the x-axis instead of seconds
plt.figure(figsize=(14, 5))
librosa.display.waveshow(samples, sr=sample_rate)

# %%
print ('Example shape ', samples.shape, 'Sample rate ', sample_rate, 'Data type', type(samples))
print (samples[22400:22420])
# Out:
# Example shape  (5636,) Sample rate  128 Data type <class 'numpy.ndarray'>
# []

# %%
sgram = librosa.stft(samples)
#librosa.display.show(sgram)

librosa.display.specshow(sgram)
# Out:
# /var/folders/3v/dsfh0t7j2x38mw1qn8qmf2z00000gn/T/ipykernel_26729/2472299652.py:4: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   librosa.display.specshow(sgram)

# %%
# use the mel-scale instead of raw frequency
sgram_mag, _ = librosa.magphase(sgram)
mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sample_rate)
librosa.display.specshow(mel_scale_sgram)

# %%
import numpy as np

# %%
# use the decibel scale to get the final Mel Spectrogram
mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
librosa.display.specshow(mel_sgram, sr=sample_rate, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
# Out:
# /Users/sgyoung/anaconda3/lib/python3.11/site-packages/librosa/display.py:1254: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   if __same_axes(x_axis, y_axis, axes.get_xlim(), axes.get_ylim()) and auto_aspect:

# %%
#Spectrogram is a 2D numpy array
print(type(mel_sgram), mel_sgram.shape)
# <class 'numpy.ndarray'> (128, 134)
# Out:
# <class 'numpy.ndarray'> (128, 12)

# %%
# ----------------------------
# Prepare training data from Metadata file
# ----------------------------
import pandas as pd
from pathlib import Path

download_path = Path.cwd()/'UrbanSound8K'

# Read metadata file
metadata_file = download_path/'metadata'/'UrbanSound8K.csv'
df = pd.read_csv(metadata_file)
df.head()

# Construct file path by concatenating fold and file name
df['relative_path'] = '/fold' + df['fold'].astype(str) + '/' + df['slice_file_name'].astype(str)

# Take relevant columns
df = df[['relative_path', 'classID']]
df.head()
view raw
# Out:
#   Cell In[39], line 20
#     view raw
#          ^
# SyntaxError: invalid syntax

# %%
samples
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
